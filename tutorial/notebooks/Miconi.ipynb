# %% [markdown]
# # Miconi network
#
# Reward-modulated recurrent network based on:
#
# > Miconi T. (2017). Biologically plausible learning in recurrent neural networks reproduces neural dynamics observed during cognitive tasks. eLife 6:e20899. doi:10.7554/eLife.20899

# %%
# !pip install ANNarchy

# %%
from ANNarchy import *
clear()
setup(dt=1.0)
# Out:
# ANNarchy 4.7 (4.7.1.5) on darwin (posix).

# %% [markdown]
# Each neuron in the reservoir follows the following equations:
#
# $$
#     \tau \frac{dx(t)}{dt} + x(t) = \sum_\text{input} W^\text{IN} \, r^\text{IN}(t) + \sum_\text{rec} W^\text{REC} \, r(t) + \xi(t)
# $$
#
# $$
#     r(t) = \tanh(x(t))
# $$
#
# where $\xi(t)$ is a random perturbation at 3 Hz, with an amplitude randomly sampled between $-A$ and $+A$.
#
# We additionally keep track of the mean firing rate with a sliding average:
#
# $$
#     \tilde{x}(t) = \alpha \, \tilde{x}(t) + (1 - \alpha) \, x(t)
# $$
#
# Some neurons keep a constant rate throughout learning (1 or -1) to provide some bias to the other neurons.

# %%
neuron = Neuron(
    parameters = """
        tau = 30.0 : population # Time constant
        constant = 0.0 # The four first neurons have constant rates
        alpha = 0.05 : population # To compute the sliding mean
        f = 3.0 : population # Frequency of the perturbation
        A = 16. : population # Perturbation amplitude. dt*A/tau should be 0.5...
    """,
    equations="""
        # Perturbation
        perturbation = if Uniform(0.0, 1.0) < f/1000.: 1.0 else: 0.0 
        noise = if perturbation > 0.5: A*Uniform(-1.0, 1.0) else: 0.0

        # ODE for x
        x += dt*(sum(in) + sum(exc) - x + noise)/tau

        # Output r
        rprev = r
        r = if constant == 0.0: tanh(x) else: tanh(constant)

        # Sliding mean
        delta_x = x - x_mean
        x_mean = alpha * x_mean + (1 - alpha) * x
    """
)

# %% [markdown]
# The learning rule is defined by a trace $e_{i, j}(t)$ for each synapse $i \rightarrow j$ incremented at each time step with:
#
# $$
#     e_{i, j}(t) = e_{i, j}(t-1) + (r_i (t) \, x_j(t))^3
# $$
#
# At the end $T$ of a trial, a normalized reward $(R -R_\text{mean})$ is delivered and all weights are updated using:
#
# $$
#     \Delta w_{i, j} = - \eta \,  e_{i, j}(T) \, (R -R_\text{mean})
# $$
#
# All traces are then reset to 0 for the next trial. Weight changes are clamped between -0.0003 and 0.0003.
#
# As ANNarchy applies the synaptic equations at each time step, we need to introduce a boolean `learning_phase` which performs trace integration when 0, weight update when 1.

# %%
synapse = Synapse(
    parameters="""
        eta = 0.5 : projection # Learning rate
        learning_phase = 0.0 : projection # Flag to allow learning only at the end of a trial
        error = 0.0 : projection # Reward received
        mean_error = 0.0 : projection # Mean Reward received
        max_weight_change = 0.0003 : projection # Clip the weight changes
    """,
    equations="""
        # Trace
        trace += if learning_phase < 0.5:
                    power(pre.rprev * (post.delta_x), 3)
                 else:
                    0.0

        # Weight update only at the end of the trial
        delta_w = if learning_phase > 0.5:
                eta * trace * (mean_error) * (error - mean_error)
             else:
                 0.0 : min=-max_weight_change, max=max_weight_change
        w -= if learning_phase > 0.5:
                delta_w
             else:
                 0.0
    """
)

# %% [markdown]
# We model the DNMS task of Miconi. The RC network has two inputs A and B. The reservoir has 200 neurons, 3 of which have constant rates.

# %%
# Input population
inp = Population(2, Neuron(parameters="r=0.0"))

# Recurrent population
N = 200
pop = Population(N, neuron)
pop[1].constant = 1.0
pop[10].constant = 1.0
pop[11].constant = -1.0
pop.x = Uniform(-0.1, 0.1)

# %% [markdown]
# Input weights are uniformly distributes between -1 and 1.
#
# Recurrent weights and normally distributed, with a coupling strength of $g=1.5$ (edge of chaos).
#
# Connections are all-to-all (fully connected).

# %%
# Input weights
Wi = Projection(inp, pop, 'in')
Wi.connect_all_to_all(weights=Uniform(-1.0, 1.0))

# Recurrent weights
g = 1.5
Wrec = Projection(pop, pop, 'exc', synapse)
Wrec.connect_all_to_all(weights=Normal(0., g/np.sqrt(N)), allow_self_connections=True)

# %%
compile()

# %% [markdown]
# The output of the reservoir is chosen to be the neuron of index 100.

# %%
output_neuron = 100

# %% [markdown]
# We record the rates inside the reservoir:

# %%
m = Monitor(pop, ['r'])

# %% [markdown]
# Parameters defining the task:

# %%
# Compute the mean reward per trial
R_mean = np.zeros((2, 2))
alpha = 0.75 # 0.33

# Durations
d_stim = 200
d_delay= 200
d_response = 400
d_execution= 200

# %% [markdown]
# Definition of a DNMS trial (AA, AB, BA, BB):

# %%
def dnms_trial(trial, first, second, R_mean, printing=False):
    traces = []

    # Reinitialize network
    pop.x = Uniform(-0.1, 0.1).get_values(N)
    pop.r = np.tanh(pop.x)
    pop[1].r = np.tanh(1.0)
    pop[10].r = np.tanh(1.0)
    pop[11].r = np.tanh(-1.0)

    # First input
    inp[first].r = 1.0
    simulate(d_stim)
    
    # Delay
    inp.r = 0.0
    simulate(d_delay)
    
    # Second input
    inp[second].r = 1.0
    simulate(d_stim)
    
    # Relaxation
    inp.r = 0.0
    simulate(d_response)
    
    # Read the output
    rec = m.get()
    
    # Compute the target
    target = 0.98 if first != second else -0.98
    
    # Response is over the last 200 ms
    output = rec['r'][-int(d_execution):, output_neuron] # neuron 100 over the last 200 ms
    
    # Compute the error
    error = np.mean(np.abs(target - output))
    if printing:
        print('Target:', target, '\tOutput:', "%0.3f" % np.mean(output), '\tError:',  "%0.3f" % error, '\tMean:', "%0.3f" % R_mean[first, second])
    
    # The first 25 trial do not learn, to let R_mean get realistic values
    if trial > 25:
        # Apply the learning rule
        Wrec.learning_phase = 1.0
        Wrec.error = error
        Wrec.mean_error = R_mean[first, second]
        # Learn for one step
        step()
        # Reset the traces
        Wrec.learning_phase = 0.0
        Wrec.trace = 0.0
        _ = m.get() # to flush the recording of the last step

    # Update the mean reward
    R_mean[first, second] = alpha * R_mean[first, second] + (1.- alpha) * error

    return rec, traces, R_mean

# %%
# Initial weights
init_w = Wrec.w

# Many trials of each type
mean_rewards = []
try:
    for trial in range(1500):
        print('Trial', trial)
        recordsAA, tracesAA, R_mean = dnms_trial (trial, 0, 0, R_mean, printing=True)
        recordsAB, tracesAB, R_mean = dnms_trial (trial, 0, 1, R_mean, printing=True)
        recordsBA, tracesBA, R_mean = dnms_trial (trial, 1, 0, R_mean, printing=True)
        recordsBB, tracesBB, R_mean = dnms_trial (trial, 1, 1, R_mean, printing=True)
        if trial == 0:
            initialAA = recordsAA['r']
            initialAB = recordsAB['r']
            initialBA = recordsBA['r']
            initialBB = recordsBB['r']

        mean_rewards.append(np.mean(R_mean))
except KeyboardInterrupt:
    pass

# Final weights
final_w = Wrec.w
# Out:
# Trial 0
# Target: -0.98 	Output: 0.727 	Error: 1.707 	Mean: 0.000
# Target: 0.98 	Output: 0.082 	Error: 0.898 	Mean: 0.000
# Target: 0.98 	Output: 0.640 	Error: 0.340 	Mean: 0.000
# Target: -0.98 	Output: 0.091 	Error: 1.071 	Mean: 0.000
# Trial 1
# Target: -0.98 	Output: 0.824 	Error: 1.804 	Mean: 0.427
# Target: 0.98 	Output: -0.213 	Error: 1.193 	Mean: 0.225
# Target: 0.98 	Output: 0.821 	Error: 0.159 	Mean: 0.085
# Target: -0.98 	Output: 0.234 	Error: 1.214 	Mean: 0.268
# Trial 2
# Target: -0.98 	Output: 0.786 	Error: 1.766 	Mean: 0.771
# Target: 0.98 	Output: -0.035 	Error: 1.015 	Mean: 0.467
# Target: 0.98 	Output: 0.844 	Error: 0.136 	Mean: 0.104
# Target: -0.98 	Output: 0.161 	Error: 1.141 	Mean: 0.504
# Trial 3
# Target: -0.98 	Output: 0.440 	Error: 1.420 	Mean: 1.020
# Target: 0.98 	Output: -0.056 	Error: 1.036 	Mean: 0.604
# Target: 0.98 	Output: 0.757 	Error: 0.223 	Mean: 0.112
# Target: -0.98 	Output: 0.086 	Error: 1.066 	Mean: 0.664
# Trial 4
# Target: -0.98 	Output: 0.721 	Error: 1.701 	Mean: 1.120
# Target: 0.98 	Output: 0.102 	Error: 0.878 	Mean: 0.712
# Target: 0.98 	Output: 0.845 	Error: 0.135 	Mean: 0.140
# Target: -0.98 	Output: 0.159 	Error: 1.139 	Mean: 0.764
# Trial 5
# Target: -0.98 	Output: 0.667 	Error: 1.647 	Mean: 1.265
# Target: 0.98 	Output: 0.022 	Error: 0.958 	Mean: 0.753
# Target: 0.98 	Output: 0.833 	Error: 0.147 	Mean: 0.138
# Target: -0.98 	Output: 0.414 	Error: 1.394 	Mean: 0.858
# Trial 6
# Target: -0.98 	Output: 0.753 	Error: 1.733 	Mean: 1.361
# Target: 0.98 	Output: -0.076 	Error: 1.056 	Mean: 0.804
# Target: 0.98 	Output: 0.648 	Error: 0.332 	Mean: 0.141
# Target: -0.98 	Output: 0.260 	Error: 1.240 	Mean: 0.992
# Trial 7
# Target: -0.98 	Output: 0.717 	Error: 1.697 	Mean: 1.454
# Target: 0.98 	Output: 0.044 	Error: 0.936 	Mean: 0.867
# Target: 0.98 	Output: 0.770 	Error: 0.210 	Mean: 0.188
# Target: -0.98 	Output: 0.177 	Error: 1.157 	Mean: 1.054
# Trial 8
# Target: -0.98 	Output: 0.675 	Error: 1.655 	Mean: 1.515
# Target: 0.98 	Output: -0.024 	Error: 1.004 	Mean: 0.885
# Target: 0.98 	Output: 0.786 	Error: 0.194 	Mean: 0.194
# Target: -0.98 	Output: 0.294 	Error: 1.274 	Mean: 1.080
# Trial 9
# Target: -0.98 	Output: 0.734 	Error: 1.714 	Mean: 1.550
# Target: 0.98 	Output: 0.024 	Error: 0.956 	Mean: 0.914
# Target: 0.98 	Output: 0.774 	Error: 0.206 	Mean: 0.194
# Target: -0.98 	Output: 0.076 	Error: 1.056 	Mean: 1.128
# Trial 10
# Target: -0.98 	Output: 0.712 	Error: 1.692 	Mean: 1.591
# Target: 0.98 	Output: 0.004 	Error: 0.976 	Mean: 0.925
# Target: 0.98 	Output: 0.640 	Error: 0.340 	Mean: 0.197
# Target: -0.98 	Output: 0.109 	Error: 1.089 	Mean: 1.110
# Trial 11
# Target: -0.98 	Output: 0.698 	Error: 1.678 	Mean: 1.616
# Target: 0.98 	Output: 0.013 	Error: 0.967 	Mean: 0.937
# Target: 0.98 	Output: 0.720 	Error: 0.260 	Mean: 0.233
# Target: -0.98 	Output: 0.545 	Error: 1.525 	Mean: 1.105
# Trial 12
# Target: -0.98 	Output: 0.794 	Error: 1.774 	Mean: 1.631
# Target: 0.98 	Output: 0.023 	Error: 0.957 	Mean: 0.945
# Target: 0.98 	Output: 0.752 	Error: 0.228 	Mean: 0.239
# Target: -0.98 	Output: 0.554 	Error: 1.534 	Mean: 1.210
# Trial 13
# Target: -0.98 	Output: 0.540 	Error: 1.520 	Mean: 1.667
# Target: 0.98 	Output: 0.048 	Error: 0.932 	Mean: 0.948
# Target: 0.98 	Output: 0.693 	Error: 0.287 	Mean: 0.237
# Target: -0.98 	Output: 0.205 	Error: 1.185 	Mean: 1.291
# Trial 14
# Target: -0.98 	Output: 0.649 	Error: 1.629 	Mean: 1.630
# Target: 0.98 	Output: -0.104 	Error: 1.084 	Mean: 0.944
# Target: 0.98 	Output: 0.764 	Error: 0.216 	Mean: 0.249
# Target: -0.98 	Output: 0.257 	Error: 1.237 	Mean: 1.264
# Trial 15
# Target: -0.98 	Output: 0.699 	Error: 1.679 	Mean: 1.630
# Target: 0.98 	Output: 0.110 	Error: 0.870 	Mean: 0.979
# Target: 0.98 	Output: 0.781 	Error: 0.199 	Mean: 0.241
# Target: -0.98 	Output: 0.439 	Error: 1.419 	Mean: 1.257
# Trial 16
# Target: -0.98 	Output: 0.765 	Error: 1.745 	Mean: 1.642
# Target: 0.98 	Output: 0.110 	Error: 0.870 	Mean: 0.952
# Target: 0.98 	Output: 0.747 	Error: 0.233 	Mean: 0.230
# Target: -0.98 	Output: 0.113 	Error: 1.093 	Mean: 1.298
# Trial 17
# Target: -0.98 	Output: 0.753 	Error: 1.733 	Mean: 1.668
# Target: 0.98 	Output: 0.298 	Error: 0.682 	Mean: 0.931
# Target: 0.98 	Output: 0.818 	Error: 0.162 	Mean: 0.231
# Target: -0.98 	Output: 0.393 	Error: 1.373 	Mean: 1.247
# Trial 18
# Target: -0.98 	Output: 0.734 	Error: 1.714 	Mean: 1.684
# Target: 0.98 	Output: -0.006 	Error: 0.986 	Mean: 0.869
# Target: 0.98 	Output: 0.830 	Error: 0.150 	Mean: 0.214
# Target: -0.98 	Output: 0.175 	Error: 1.155 	Mean: 1.278
# Trial 19
# Target: -0.98 	Output: 0.670 	Error: 1.650 	Mean: 1.691
# Target: 0.98 	Output: 0.206 	Error: 0.774 	Mean: 0.898
# Target: 0.98 	Output: 0.745 	Error: 0.235 	Mean: 0.198
# Target: -0.98 	Output: 0.083 	Error: 1.063 	Mean: 1.247
# Trial 20
# Target: -0.98 	Output: 0.655 	Error: 1.635 	Mean: 1.681
# Target: 0.98 	Output: -0.041 	Error: 1.021 	Mean: 0.867
# Target: 0.98 	Output: 0.792 	Error: 0.188 	Mean: 0.207
# Target: -0.98 	Output: 0.592 	Error: 1.572 	Mean: 1.201
# Trial 21
# Target: -0.98 	Output: 0.625 	Error: 1.605 	Mean: 1.670
# Target: 0.98 	Output: 0.022 	Error: 0.958 	Mean: 0.905
# Target: 0.98 	Output: 0.753 	Error: 0.227 	Mean: 0.202
# Target: -0.98 	Output: 0.127 	Error: 1.107 	Mean: 1.294
# Trial 22
# Target: -0.98 	Output: 0.650 	Error: 1.630 	Mean: 1.653
# Target: 0.98 	Output: -0.034 	Error: 1.014 	Mean: 0.919
# Target: 0.98 	Output: 0.621 	Error: 0.359 	Mean: 0.208
# Target: -0.98 	Output: 0.237 	Error: 1.217 	Mean: 1.247
# Trial 23
# Target: -0.98 	Output: 0.717 	Error: 1.697 	Mean: 1.648
# Target: 0.98 	Output: 0.047 	Error: 0.933 	Mean: 0.942
# Target: 0.98 	Output: 0.738 	Error: 0.242 	Mean: 0.246
# Target: -0.98 	Output: 0.202 	Error: 1.182 	Mean: 1.240
# Trial 24
# Target: -0.98 	Output: 0.803 	Error: 1.783 	Mean: 1.660
# Target: 0.98 	Output: 0.223 	Error: 0.757 	Mean: 0.940
# Target: 0.98 	Output: 0.738 	Error: 0.242 	Mean: 0.245
# Target: -0.98 	Output: 0.140 	Error: 1.120 	Mean: 1.225
# Trial 25
# Target: -0.98 	Output: 0.584 	Error: 1.564 	Mean: 1.691
# Target: 0.98 	Output: 0.145 	Error: 0.835 	Mean: 0.894
# Target: 0.98 	Output: 0.677 	Error: 0.303 	Mean: 0.244
# Target: -0.98 	Output: 0.335 	Error: 1.315 	Mean: 1.199
# Trial 26
# Target: -0.98 	Output: 0.675 	Error: 1.655 	Mean: 1.659
# Target: 0.98 	Output: 0.032 	Error: 0.948 	Mean: 0.879
# Target: 0.98 	Output: 0.691 	Error: 0.289 	Mean: 0.259
# Target: -0.98 	Output: 0.409 	Error: 1.389 	Mean: 1.228
# Trial 27
# Target: -0.98 	Output: 0.790 	Error: 1.770 	Mean: 1.658
# Target: 0.98 	Output: 0.060 	Error: 0.920 	Mean: 0.896
# Target: 0.98 	Output: 0.770 	Error: 0.210 	Mean: 0.266
# Target: -0.98 	Output: 0.194 	Error: 1.174 	Mean: 1.268
# Trial 28
# Target: -0.98 	Output: 0.615 	Error: 1.595 	Mean: 1.686
# Target: 0.98 	Output: 0.555 	Error: 0.425 	Mean: 0.902
# Target: 0.98 	Output: 0.773 	Error: 0.207 	Mean: 0.252
# Target: -0.98 	Output: 0.359 	Error: 1.339 	Mean: 1.245
# Trial 29
# Target: -0.98 	Output: 0.519 	Error: 1.499 	Mean: 1.663
# Target: 0.98 	Output: 0.147 	Error: 0.833 	Mean: 0.783
# Target: 0.98 	Output: 0.816 	Error: 0.164 	Mean: 0.241
# Target: -0.98 	Output: 0.258 	Error: 1.238 	Mean: 1.268
# Trial 30
# Target: -0.98 	Output: 0.689 	Error: 1.669 	Mean: 1.622
# Target: 0.98 	Output: 0.505 	Error: 0.475 	Mean: 0.796
# Target: 0.98 	Output: 0.823 	Error: 0.157 	Mean: 0.222
# Target: -0.98 	Output: 0.216 	Error: 1.196 	Mean: 1.261
# Trial 31
# Target: -0.98 	Output: 0.604 	Error: 1.584 	Mean: 1.634
# Target: 0.98 	Output: 0.128 	Error: 0.852 	Mean: 0.716
# Target: 0.98 	Output: 0.807 	Error: 0.173 	Mean: 0.205
# Target: -0.98 	Output: 0.325 	Error: 1.305 	Mean: 1.244
# Trial 32
# Target: -0.98 	Output: 0.564 	Error: 1.544 	Mean: 1.621
# Target: 0.98 	Output: 0.567 	Error: 0.413 	Mean: 0.750
# Target: 0.98 	Output: 0.789 	Error: 0.191 	Mean: 0.197
# Target: -0.98 	Output: 0.333 	Error: 1.313 	Mean: 1.260
# Trial 33
# Target: -0.98 	Output: 0.804 	Error: 1.784 	Mean: 1.602
# Target: 0.98 	Output: 0.577 	Error: 0.403 	Mean: 0.666
# Target: 0.98 	Output: 0.741 	Error: 0.239 	Mean: 0.196
# Target: -0.98 	Output: 0.060 	Error: 1.040 	Mean: 1.273
# Trial 34
# Target: -0.98 	Output: 0.746 	Error: 1.726 	Mean: 1.647
# Target: 0.98 	Output: 0.456 	Error: 0.524 	Mean: 0.600
# Target: 0.98 	Output: 0.742 	Error: 0.238 	Mean: 0.207
# Target: -0.98 	Output: 0.049 	Error: 1.029 	Mean: 1.215
# Trial 35
# Target: -0.98 	Output: 0.487 	Error: 1.467 	Mean: 1.667
# Target: 0.98 	Output: 0.368 	Error: 0.612 	Mean: 0.581
# Target: 0.98 	Output: 0.718 	Error: 0.262 	Mean: 0.215
# Target: -0.98 	Output: 0.177 	Error: 1.157 	Mean: 1.168
# Trial 36
# Target: -0.98 	Output: 0.529 	Error: 1.509 	Mean: 1.617
# Target: 0.98 	Output: 0.403 	Error: 0.577 	Mean: 0.589
# Target: 0.98 	Output: 0.575 	Error: 0.405 	Mean: 0.226
# Target: -0.98 	Output: 0.295 	Error: 1.275 	Mean: 1.166
# Trial 37
# Target: -0.98 	Output: 0.464 	Error: 1.444 	Mean: 1.590
# Target: 0.98 	Output: 0.511 	Error: 0.469 	Mean: 0.586
# Target: 0.98 	Output: 0.764 	Error: 0.216 	Mean: 0.271
# Target: -0.98 	Output: 0.471 	Error: 1.451 	Mean: 1.193
# Trial 38
# Target: -0.98 	Output: 0.682 	Error: 1.662 	Mean: 1.553
# Target: 0.98 	Output: 0.384 	Error: 0.596 	Mean: 0.556
# Target: 0.98 	Output: 0.819 	Error: 0.161 	Mean: 0.257
# Target: -0.98 	Output: 0.330 	Error: 1.310 	Mean: 1.257
# Trial 39
# Target: -0.98 	Output: 0.539 	Error: 1.519 	Mean: 1.581
# Target: 0.98 	Output: 0.348 	Error: 0.632 	Mean: 0.566
# Target: 0.98 	Output: 0.688 	Error: 0.292 	Mean: 0.233
# Target: -0.98 	Output: 0.287 	Error: 1.267 	Mean: 1.271
# Trial 40
# Target: -0.98 	Output: 0.559 	Error: 1.539 	Mean: 1.565
# Target: 0.98 	Output: 0.580 	Error: 0.400 	Mean: 0.583
# Target: 0.98 	Output: 0.683 	Error: 0.297 	Mean: 0.248
# Target: -0.98 	Output: 0.058 	Error: 1.038 	Mean: 1.270
# Trial 41
# Target: -0.98 	Output: 0.553 	Error: 1.533 	Mean: 1.559
# Target: 0.98 	Output: 0.422 	Error: 0.558 	Mean: 0.537
# Target: 0.98 	Output: 0.659 	Error: 0.321 	Mean: 0.260
# Target: -0.98 	Output: -0.102 	Error: 0.878 	Mean: 1.212
# Trial 42
# Target: -0.98 	Output: 0.585 	Error: 1.565 	Mean: 1.552
# Target: 0.98 	Output: 0.560 	Error: 0.420 	Mean: 0.542
# Target: 0.98 	Output: 0.578 	Error: 0.402 	Mean: 0.275
# Target: -0.98 	Output: -0.042 	Error: 0.938 	Mean: 1.128
# Trial 43
# Target: -0.98 	Output: 0.577 	Error: 1.557 	Mean: 1.555
# Target: 0.98 	Output: 0.555 	Error: 0.425 	Mean: 0.512
# Target: 0.98 	Output: 0.669 	Error: 0.311 	Mean: 0.307
# Target: -0.98 	Output: 0.321 	Error: 1.301 	Mean: 1.081
# Trial 44
# Target: -0.98 	Output: 0.415 	Error: 1.395 	Mean: 1.556
# Target: 0.98 	Output: 0.405 	Error: 0.575 	Mean: 0.490
# Target: 0.98 	Output: 0.616 	Error: 0.364 	Mean: 0.308
# Target: -0.98 	Output: -0.013 	Error: 0.967 	Mean: 1.136
# Trial 45
# Target: -0.98 	Output: 0.311 	Error: 1.291 	Mean: 1.516
# Target: 0.98 	Output: 0.596 	Error: 0.384 	Mean: 0.511
# Target: 0.98 	Output: 0.710 	Error: 0.270 	Mean: 0.322
# Target: -0.98 	Output: 0.165 	Error: 1.145 	Mean: 1.094
# Trial 46
# Target: -0.98 	Output: 0.248 	Error: 1.228 	Mean: 1.459
# Target: 0.98 	Output: 0.619 	Error: 0.361 	Mean: 0.479
# Target: 0.98 	Output: 0.658 	Error: 0.322 	Mean: 0.309
# Target: -0.98 	Output: 0.219 	Error: 1.199 	Mean: 1.106
# Trial 47
# Target: -0.98 	Output: 0.368 	Error: 1.348 	Mean: 1.402
# Target: 0.98 	Output: 0.655 	Error: 0.325 	Mean: 0.450
# Target: 0.98 	Output: 0.424 	Error: 0.556 	Mean: 0.312
# Target: -0.98 	Output: 0.286 	Error: 1.266 	Mean: 1.129
# Trial 48
# Target: -0.98 	Output: 0.459 	Error: 1.439 	Mean: 1.388
# Target: 0.98 	Output: 0.869 	Error: 0.111 	Mean: 0.163
# ...
# Trial 1432
# Target: -0.98 	Output: -0.973 	Error: 0.018 	Mean: 0.032
# Target: 0.98 	Output: 0.976 	Error: 0.013 	Mean: 0.024
# Target: 0.98 	Output: 0.992 	Error: 0.013 	Mean: 0.020
# Target: -0.98 	Output: -0.963 	Error: 0.033 	Mean: 0.045
# Trial 1433
# Target: -0.98 	Output: -0.944 	Error: 0.054 	Mean: 0.029
# Target: 0.98 	Output: 0.962 	Error: 0.020 	Mean: 0.021
# Target: 0.98 	Output: 0.984 	Error: 0.017 	Mean: 0.019
# Target: -0.98 	Output: -0.875 	Error: 0.115 	Mean: 0.042
# Trial 1434
# Target: -0.98 	Output: -0.960 	Error: 0.034 	Mean: 0.035
# Target: 0.98 	Output: 0.963 	Error: 0.020 	Mean: 0.021
# Target: 0.98 	Output: 0.966 	Error: 0.033 	Mean: 0.018
# Target: -0.98 	Output: -0.934 	Error: 0.049 	Mean: 0.060
# Trial 1435
# Target: -0.98 	Output: -0.973 	Error: 0.024 	Mean: 0.035
# Target: 0.98 	Output: 0.958 	Error: 0.024 	Mean: 0.021
# Target: 0.98 	Output: 0.974 	Error: 0.025 	Mean: 0.022
# Target: -0.98 	Output: -0.937 	Error: 0.052 	Mean: 0.057
# Trial 1436
# Target: -0.98 	Output: -0.955 	Error: 0.042 	Mean: 0.032
# Target: 0.98 	Output: 0.980 	Error: 0.011 	Mean: 0.022
# Target: 0.98 	Output: 0.984 	Error: 0.016 	Mean: 0.023
# Target: -0.98 	Output: -0.928 	Error: 0.058 	Mean: 0.056
# Trial 1437
# Target: -0.98 	Output: -0.965 	Error: 0.029 	Mean: 0.034
# Target: 0.98 	Output: 0.978 	Error: 0.009 	Mean: 0.019
# Target: 0.98 	Output: 0.990 	Error: 0.017 	Mean: 0.021
# Target: -0.98 	Output: -0.956 	Error: 0.032 	Mean: 0.056
# Trial 1438
# Target: -0.98 	Output: -0.974 	Error: 0.023 	Mean: 0.033
# Target: 0.98 	Output: 0.934 	Error: 0.046 	Mean: 0.016
# Target: 0.98 	Output: 0.989 	Error: 0.012 	Mean: 0.020
# Target: -0.98 	Output: -0.964 	Error: 0.029 	Mean: 0.050
# Trial 1439
# Target: -0.98 	Output: -0.919 	Error: 0.075 	Mean: 0.031
# Target: 0.98 	Output: 0.961 	Error: 0.022 	Mean: 0.024
# Target: 0.98 	Output: 0.985 	Error: 0.018 	Mean: 0.018
# Target: -0.98 	Output: -0.978 	Error: 0.020 	Mean: 0.045
# Trial 1440
# Target: -0.98 	Output: -0.977 	Error: 0.021 	Mean: 0.042
# Target: 0.98 	Output: 0.959 	Error: 0.028 	Mean: 0.023
# Target: 0.98 	Output: 0.958 	Error: 0.028 	Mean: 0.018
# Target: -0.98 	Output: -0.977 	Error: 0.018 	Mean: 0.039
# Trial 1441
# Target: -0.98 	Output: -0.977 	Error: 0.020 	Mean: 0.036
# Target: 0.98 	Output: 0.978 	Error: 0.015 	Mean: 0.025
# Target: 0.98 	Output: 0.975 	Error: 0.024 	Mean: 0.020
# Target: -0.98 	Output: -0.960 	Error: 0.035 	Mean: 0.034
# Trial 1442
# Target: -0.98 	Output: -0.961 	Error: 0.023 	Mean: 0.032
# Target: 0.98 	Output: 0.978 	Error: 0.015 	Mean: 0.022
# Target: 0.98 	Output: 0.985 	Error: 0.017 	Mean: 0.021
# Target: -0.98 	Output: -0.973 	Error: 0.024 	Mean: 0.034
# Trial 1443
# Target: -0.98 	Output: -0.962 	Error: 0.022 	Mean: 0.030
# Target: 0.98 	Output: 0.969 	Error: 0.016 	Mean: 0.020
# Target: 0.98 	Output: 0.961 	Error: 0.038 	Mean: 0.020
# Target: -0.98 	Output: -0.963 	Error: 0.028 	Mean: 0.032
# Trial 1444
# Target: -0.98 	Output: -0.979 	Error: 0.013 	Mean: 0.028
# Target: 0.98 	Output: 0.977 	Error: 0.015 	Mean: 0.019
# Target: 0.98 	Output: 0.955 	Error: 0.039 	Mean: 0.025
# Target: -0.98 	Output: -0.982 	Error: 0.017 	Mean: 0.031
# Trial 1445
# Target: -0.98 	Output: -0.975 	Error: 0.024 	Mean: 0.024
# Target: 0.98 	Output: 0.966 	Error: 0.020 	Mean: 0.018
# Target: 0.98 	Output: 0.861 	Error: 0.120 	Mean: 0.028
# Target: -0.98 	Output: -0.936 	Error: 0.049 	Mean: 0.027
# Trial 1446
# Target: -0.98 	Output: -0.972 	Error: 0.025 	Mean: 0.024
# Target: 0.98 	Output: 0.950 	Error: 0.032 	Mean: 0.019
# Target: 0.98 	Output: 0.961 	Error: 0.038 	Mean: 0.051
# Target: -0.98 	Output: -0.957 	Error: 0.034 	Mean: 0.032
# Trial 1447
# Target: -0.98 	Output: -0.964 	Error: 0.025 	Mean: 0.024
# Target: 0.98 	Output: 0.953 	Error: 0.028 	Mean: 0.022
# Target: 0.98 	Output: 0.987 	Error: 0.015 	Mean: 0.048
# Target: -0.98 	Output: -0.979 	Error: 0.019 	Mean: 0.033
# Trial 1448
# Target: -0.98 	Output: -0.970 	Error: 0.024 	Mean: 0.024
# Target: 0.98 	Output: 0.959 	Error: 0.021 	Mean: 0.024
# Target: 0.98 	Output: 0.960 	Error: 0.032 	Mean: 0.040
# Target: -0.98 	Output: -0.973 	Error: 0.025 	Mean: 0.029
# Trial 1449
# Target: -0.98 	Output: -0.958 	Error: 0.035 	Mean: 0.024
# Target: 0.98 	Output: 0.975 	Error: 0.012 	Mean: 0.023
# Target: 0.98 	Output: 0.985 	Error: 0.018 	Mean: 0.038
# Target: -0.98 	Output: -0.976 	Error: 0.019 	Mean: 0.028
# Trial 1450
# Target: -0.98 	Output: -0.964 	Error: 0.034 	Mean: 0.027
# Target: 0.98 	Output: 0.969 	Error: 0.015 	Mean: 0.020
# Target: 0.98 	Output: 0.955 	Error: 0.043 	Mean: 0.033
# Target: -0.98 	Output: -0.950 	Error: 0.041 	Mean: 0.026
# Trial 1451
# Target: -0.98 	Output: -0.969 	Error: 0.026 	Mean: 0.029
# Target: 0.98 	Output: 0.961 	Error: 0.023 	Mean: 0.019
# Target: 0.98 	Output: 0.995 	Error: 0.015 	Mean: 0
# Target: 0.98 	Output: 0.982 	Error: 0.009 	Mean: 0.026
# Target: 0.98 	Output: 0.593 	Error: 0.387 	Mean: 0.103
# Target: -0.98 	Output: -0.951 	Error: 0.037 	Mean: 0.028
# Trial 1462
# Target: -0.98 	Output: -0.973 	Error: 0.020 	Mean: 0.026
# Target: 0.98 	Output: 0.972 	Error: 0.013 	Mean: 0.022
# Target: 0.98 	Output: 0.380 	Error: 0.602 	Mean: 0.174
# Target: -0.98 	Output: -0.969 	Error: 0.024 	Mean: 0.031
# Trial 1463
# Target: -0.98 	Output: -0.976 	Error: 0.020 	Mean: 0.025
# Target: 0.98 	Output: 0.970 	Error: 0.021 	Mean: 0.020
# Target: 0.98 	Output: 0.990 	Error: 0.012 	Mean: 0.281
# Target: -0.98 	Output: -0.972 	Error: 0.025 	Mean: 0.029
# Trial 1464
# Target: -0.98 	Output: -0.984 	Error: 0.016 	Mean: 0.024
# Target: 0.98 	Output: 0.960 	Error: 0.026 	Mean: 0.020
# Target: 0.98 	Output: 0.989 	Error: 0.017 	Mean: 0.214
# Target: -0.98 	Output: -0.974 	Error: 0.024 	Mean: 0.028
# Trial 1465
# Target: -0.98 	Output: -0.917 	Error: 0.079 	Mean: 0.022
# Target: 0.98 	Output: 0.954 	Error: 0.029 	Mean: 0.021
# Target: 0.98 	Output: 0.992 	Error: 0.013 	Mean: 0.164
# Target: -0.98 	Output: -0.978 	Error: 0.020 	Mean: 0.027
# Trial 1466
# Target: -0.98 	Output: -0.982 	Error: 0.018 	Mean: 0.036
# Target: 0.98 	Output: 0.970 	Error: 0.013 	Mean: 0.023
# Target: 0.98 	Output: 0.990 	Error: 0.011 	Mean: 0.127
# Target: -0.98 	Output: -0.985 	Error: 0.016 	Mean: 0.025
# Trial 1467
# Target: -0.98 	Output: -0.926 	Error: 0.070 	Mean: 0.031
# Target: 0.98 	Output: 0.924 	Error: 0.058 	Mean: 0.021
# Target: 0.98 	Output: 0.990 	Error: 0.014 	Mean: 0.098
# Target: -0.98 	Output: -0.972 	Error: 0.022 	Mean: 0.023
# Trial 1468
# Target: -0.98 	Output: -0.969 	Error: 0.022 	Mean: 0.041
# Target: 0.98 	Output: 0.837 	Error: 0.143 	Mean: 0.030
# Target: 0.98 	Output: 0.988 	Error: 0.011 	Mean: 0.077
# Target: -0.98 	Output: -0.972 	Error: 0.024 	Mean: 0.023
# Trial 1469
# Target: -0.98 	Output: -0.973 	Error: 0.025 	Mean: 0.036
# Target: 0.98 	Output: 0.965 	Error: 0.019 	Mean: 0.058
# Target: 0.98 	Output: 0.991 	Error: 0.013 	Mean: 0.061
# Target: -0.98 	Output: -0.953 	Error: 0.038 	Mean: 0.023
# Trial 1470
# Target: -0.98 	Output: -0.964 	Error: 0.033 	Mean: 0.033
# Target: 0.98 	Output: 0.954 	Error: 0.028 	Mean: 0.048
# Target: 0.98 	Output: 0.983 	Error: 0.012 	Mean: 0.049
# Target: -0.98 	Output: -0.979 	Error: 0.021 	Mean: 0.027
# Trial 1471
# Target: -0.98 	Output: -0.964 	Error: 0.026 	Mean: 0.033
# Target: 0.98 	Output: 0.923 	Error: 0.059 	Mean: 0.043
# Target: 0.98 	Output: 0.995 	Error: 0.015 	Mean: 0.039
# Target: -0.98 	Output: -0.947 	Error: 0.048 	Mean: 0.025
# Trial 1472
# Target: -0.98 	Output: -0.964 	Error: 0.034 	Mean: 0.031
# Target: 0.98 	Output: 0.967 	Error: 0.017 	Mean: 0.047
# Target: 0.98 	Output: 0.994 	Error: 0.014 	Mean: 0.033
# Target: -0.98 	Output: -0.976 	Error: 0.019 	Mean: 0.031
# Trial 1473
# Target: -0.98 	Output: -0.947 	Error: 0.051 	Mean: 0.032
# Target: 0.98 	Output: 0.955 	Error: 0.027 	Mean: 0.040
# Target: 0.98 	Output: 0.996 	Error: 0.016 	Mean: 0.029
# Target: -0.98 	Output: -0.976 	Error: 0.022 	Mean: 0.028
# Trial 1474
# Target: -0.98 	Output: -0.975 	Error: 0.023 	Mean: 0.037
# Target: 0.98 	Output: 0.918 	Error: 0.062 	Mean: 0.036
# Target: 0.98 	Output: 0.994 	Error: 0.014 	Mean: 0.025
# Target: -0.98 	Output: -0.949 	Error: 0.041 	Mean: 0.027
# Trial 1475
# Target: -0.98 	Output: -0.930 	Error: 0.067 	Mean: 0.033
# Target: 0.98 	Output: 0.943 	Error: 0.039 	Mean: 0.043
# Target: 0.98 	Output: 0.992 	Error: 0.014 	Mean: 0.023
# Target: -0.98 	Output: -0.943 	Error: 0.050 	Mean: 0.030
# Trial 1476
# Target: -0.98 	Output: -0.953 	Error: 0.035 	Mean: 0.042
# Target: 0.98 	Output: 0.870 	Error: 0.113 	Mean: 0.042
# Target: 0.98 	Output: 0.994 	Error: 0.014 	Mean: 0.020
# Target: -0.98 	Output: -0.956 	Error: 0.034 	Mean: 0.035
# Trial 1477
# Target: -0.98 	Output: -0.954 	Error: 0.037 	Mean: 0.040
# Target: 0.98 	Output: 0.957 	Error: 0.027 	Mean: 0.060
# Target: 0.98 	Output: 0.995 	Error: 0.015 	Mean: 0.019
# Target: -0.98 	Output: -0.956 	Error: 0.040 	Mean: 0.035
# Trial 1478
# Target: -0.98 	Output: -0.971 	Error: 0.023 	Mean: 0.039
# Target: 0.98 	Output: 0.881 	Error: 0.101 	Mean: 0.052
# Target: 0.98 	Output: 0.981 	Error: 0.018 	Mean: 0.018
# Target: -0.98 	Output: -0.939 	Error: 0.050 	Mean: 0.036
# Trial 1479
# Target: -0.98 	Output: -0.947 	Error: 0.050 	Mean: 0.035
# Target: 0.98 	Output: 0.963 	Error: 0.022 	Mean: 0.064
# Target: 0.98 	Output: 0.991 	Error: 0.014 	Mean: 0.018
# Target: -0.98 	Output: -0.931 	Error: 0.060 	Mean: 0.040
# Trial 1480
# Target: -0.98 	Output: -0.980 	Error: 0.016 	Mean: 0.039
# Target: 0.98 	Output: 0.855 	Error: 0.125 	Mean: 0.054
# Target: 0.98 	Output: 0.992 	Error: 0.013 	Mean: 0.017
# Target: -0.98 	Output: -0.972 	Error: 0.022 	Mean: 0.045
# Trial 1481
# Target: -0.98 	Output: -0.930 	Error: 0.069 	Mean: 0.033
# Target: 0.98 	Output: 0.936 	Error: 0.047 	Mean: 0.071
# Target: 0.98 	Output: 0.992 	Error: 0.014 	Mean: 0.016
# Target: 0.98 	Output: 0.995 	Error: 0.015 	Mean: 0.033
# Target: -0.98 	Output: -0.972 	Error: 0.025 	Mean: 0.037
# Trial 1492
# Target: -0.98 	Output: -0.888 	Error: 0.107 	Mean: 0.034
# Target: 0.98 	Output: 0.974 	Error: 0.013 	Mean: 0.049
# Target: 0.98 	Output: 0.994 	Error: 0.014 	Mean: 0.028
# Target: -0.98 	Output: -0.956 	Error: 0.034 	Mean: 0.034
# Trial 1493
# Target: -0.98 	Output: -0.958 	Error: 0.041 	Mean: 0.052
# Target: 0.98 	Output: 0.915 	Error: 0.067 	Mean: 0.040
# Target: 0.98 	Output: 0.995 	Error: 0.015 	Mean: 0.025
# Target: -0.98 	Output: -0.972 	Error: 0.026 	Mean: 0.034
# Trial 1494
# Target: -0.98 	Output: -0.966 	Error: 0.029 	Mean: 0.049
# Target: 0.98 	Output: 0.969 	Error: 0.017 	Mean: 0.047
# Target: 0.98 	Output: 0.991 	Error: 0.014 	Mean: 0.022
# Target: -0.98 	Output: -0.932 	Error: 0.058 	Mean: 0.032
# Trial 1495
# Target: -0.98 	Output: -0.962 	Error: 0.037 	Mean: 0.044
# Target: 0.98 	Output: 0.929 	Error: 0.054 	Mean: 0.040
# Target: 0.98 	Output: 0.994 	Error: 0.014 	Mean: 0.020
# Target: -0.98 	Output: -0.941 	Error: 0.051 	Mean: 0.039
# Trial 1496
# Target: -0.98 	Output: -0.972 	Error: 0.024 	Mean: 0.043
# Target: 0.98 	Output: 0.982 	Error: 0.014 	Mean: 0.043
# Target: 0.98 	Output: 0.994 	Error: 0.014 	Mean: 0.019
# Target: -0.98 	Output: -0.971 	Error: 0.025 	Mean: 0.042
# Trial 1497
# Target: -0.98 	Output: -0.951 	Error: 0.039 	Mean: 0.038
# Target: 0.98 	Output: 0.894 	Error: 0.086 	Mean: 0.036
# Target: 0.98 	Output: 0.995 	Error: 0.015 	Mean: 0.018
# Target: -0.98 	Output: -0.970 	Error: 0.024 	Mean: 0.038
# Trial 1498
# Target: -0.98 	Output: -0.877 	Error: 0.119 	Mean: 0.038
# Target: 0.98 	Output: 0.972 	Error: 0.014 	Mean: 0.048
# Target: 0.98 	Output: 0.597 	Error: 0.388 	Mean: 0.017
# Target: -0.98 	Output: -0.958 	Error: 0.033 	Mean: 0.034
# Trial 1499
# Target: -0.98 	Output: -0.953 	Error: 0.036 	Mean: 0.058
# Target: 0.98 	Output: 0.914 	Error: 0.067 	Mean: 0.040
# Target: 0.98 	Output: 0.995 	Error: 0.015 	Mean: 0.110
# Target: -0.98 	Output: -0.913 	Error: 0.073 	Mean: 0.034

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white", palette="muted", color_codes=True)
sns.set_context("talk")

plt.figure(figsize=(10, 6))
plt.plot(mean_rewards)
plt.show()

plt.figure(figsize=(10, 10))

ax = plt.subplot(221)
ax.plot(np.mean(initialAA[:, output_neuron:output_neuron+1], axis=1), label='before')
ax.plot(np.mean(recordsAA['r'][:, output_neuron:output_neuron+1], axis=1), label='after')
ax.set_ylim((-1., 1.))
ax.legend()
ax.set_title('Output AA -1')
ax = plt.subplot(222)
ax.plot(np.mean(initialBA[:, output_neuron:output_neuron+1], axis=1), label='before')
ax.plot(np.mean(recordsBA['r'][:, output_neuron:output_neuron+1], axis=1), label='after')
ax.set_ylim((-1., 1.))
ax.legend()
ax.set_title('Output BA +1')
ax = plt.subplot(223)
ax.plot(np.mean(initialAB[:, output_neuron:output_neuron+1], axis=1), label='before')
ax.plot(np.mean(recordsAB['r'][:, output_neuron:output_neuron+1], axis=1), label='after')
ax.set_ylim((-1., 1.))
ax.set_title('Output AB +1')
ax = plt.subplot(224)
ax.plot(np.mean(initialBB[:, output_neuron:output_neuron+1], axis=1), label='before')
ax.plot(np.mean(recordsBB['r'][:, output_neuron:output_neuron+1], axis=1), label='after')
ax.set_ylim((-1., 1.))
ax.set_title('Output BB -1')
plt.savefig("performance.png")
plt.show()
